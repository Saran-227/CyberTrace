# %% [markdown]
# # CyberTrace - 03. Geographic Clustering & Zone Definitions
#
# ## Objectives
# - Explore spatial clustering of synthetic cash-out incidents.
# - Analyze geographic bounding boxes for withdrawal zones.
# - Validate separation between complaint origin coordinates and predicted cash-out zones.

# %%
# Phase 1: Notebook Stub
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
print("Geographic Clustering environment ready.")
