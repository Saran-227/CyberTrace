# %% [markdown]
# # CyberTrace - 05. Location Model Training & Comparison
#
# ## Objectives
# - Implement stratified train-test splitting.
# - Train candidate supervised classifiers:
#   1. Logistic Regression
#   2. K-Nearest Neighbors
#   3. Decision Tree
#   4. Random Forest
# - Save trained model estimators to `models/location_classifier/`.

# %%
# Phase 1: Notebook Stub
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
print("Model Training environment ready.")
